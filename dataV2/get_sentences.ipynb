# %%
import pandas as pd
import numpy as np
import nltk

import pyconll

# %%
roles_ud = pd.read_csv(
    "../../decomp/protoroles_eng_ud1.2_11082016.tsv", delimiter="\t"
    ).drop(
        columns=["Is.Pilot", "Passes.Filters", "Protocol"]
    )
roles_ud = roles_ud.loc[roles_ud["Dataset"] == "bulkfiltered"]
roles_ud["Applicable"] = roles_ud["Applicable"].apply(lambda x: 1 if x == "yes" else 0)

roles_ud.head()
# Out:
#         Dataset  Split  Annotator.ID              Sentence.ID  Pred.Token  \
# 0  bulkfiltered  train            75  en-ud-train.conllu 5620           3
# 1  bulkfiltered  train            73  en-ud-train.conllu 4472           1
# 2  bulkfiltered  train            94  en-ud-train.conllu 9843           2
# 3  bulkfiltered  train            56  en-ud-train.conllu 4484           4
# 4  bulkfiltered  train            75  en-ud-train.conllu 4484           4
#
#   Pred.Lemma Gram.Func                      Arg.Phrase  Arg.Tokens.Begin  \
# 0         be     nsubj                 the main reason                 0
# 1     e-mail      dobj                  your assistant                 2
# 2       find     nsubj                               i                 1
# 3      exist     nsubj  other &quot; guidelines &quot;                 0
# 4      exist     nsubj  other &quot; guidelines &quot;                 0
#
#    Arg.Tokens.End   Property  Response  Applicable  Sent.Grammatical
# 0               2  awareness       1.0           1               2.0
# 1               3  awareness       4.0           1               5.0
# 2               1  awareness       5.0           1               5.0
# 3               3  awareness       1.0           0               5.0
# 4               3  awareness       1.0           1               5.0

# %%
from difflib import SequenceMatcher

def get_ud_sentences(ud):
    sentences = []
    for sample in ud:
        data = sample.conll()
        words = []
        for s in data.split("\n"):
            # in ud v2, lines include meta-data and non-word tokens
            if s[0] == "#" or not s.split("\t")[0].isnumeric():
                continue
            w = s.split("\t")[1]
            words.append(w)
        text = " ".join(words)
        # text = ''.join(ch for ch in text if ch.isalnum() or ch == " ")
        sentences.append(text)
    return sentences

# %%
def close(a, b):
    return SequenceMatcher(None, a, b).ratio() > 0.75

def get_close(s1, s2):
    i = 0
    j = 0
    s1_to_2 = {}
    words_map = {}
    while i < len(s1) and j < len(s2):
        if close(s1[i], s2[j]):
            s1_to_2[i] = j
            words_map[s1[i]] = s2[j]
            i += 1
            j += 1
        else:
            if close(s1[i + 1], s2[j]):
                # discard i
                i += 1
            elif close(s1[i], s2[j + 1]):
                # discard j
                j += 1
            else:
                raise

    return s1_to_2, words_map

def align_ud_versions(ud1, ud2):
    s1 = get_ud_sentences(ud1)
    s2 = get_ud_sentences(ud2)
    return s1, get_close(s1, s2)

# %%
from spacy.training.converters import conllu_to_docs

def convert_to_spacy(conll_file):
    data = open(conll_file, encoding="utf-8")
    annotations = data.read()
    docs = list(conllu_to_docs(annotations, no_print=True))
    sents = []
    for doc in docs:
        sents += doc.sents
    return sents

path = "../datasets/eng_web_tbk"
sets = ["train.conllu", "test.conllu", "dev.conllu"]
conlls_2 = {}
conlls_1 = {}
alignments = {}
s1_sentences = {}
spacy_parses = {}

for s in sets:
    # UD version 1.2
    c1_path = f'../datasets/UD_English/en-ud-{s}'
    # UD version 2
    c2_path = f'UD_English-EWT/en_ewt-ud-{s}'

    ud1 = pyconll.load_from_file(c1_path)
    ud2 = pyconll.load_from_file(c2_path)

    conlls_1[s] = ud1
    conlls_2[s] = ud2
    s1_sentences[s], alignments[s] = align_ud_versions(ud1, ud2)
    spacy_parses[s] = convert_to_spacy(c1_path)

    assert len(s1_sentences[s]) == len(spacy_parses[s])

# %%
def remove_traces(tree):
    new_tree = tree.copy(deep=True) 
    try:
        new_tree.collapse_unary(collapsePOS=True, collapseRoot=True)
    except:
        # already collapsed
        print(tree)
        raise
    i = 0
    for _, pos in new_tree.pos():
        if "-NONE-" in pos:
            tp = new_tree.leaf_treeposition(i)
            pos_parent_tp = tp[:-2]
            pos_parent_idx = tp[-2]
            new_tree[pos_parent_tp].pop(pos_parent_idx)
        else:
            # only increment position if leaf hasn't been removed
            i += 1
    return new_tree


def get_tree(conll_id):
    genre, file, sentence = conll_id.split("-")
    file_path = path + f"/data/{genre}/penntree/{file}.xml.tree"
    with open(file_path) as f:
        doc = f.readlines()
    try:
        parsed = doc[int(sentence) - 1][1:-2]
        tree = nltk.tree.ParentedTree.fromstring(parsed)
    except ValueError:
        # contains two sentences, add "SP" to indicate sentence pair
        parsed = doc[int(sentence) - 1]
        parsed = "(SP" + parsed[1:]
        tree = nltk.tree.ParentedTree.fromstring(parsed)
        print(" ".join(tree.leaves()))
    return remove_traces(tree)


def get_sentence_parse(row, decomp_id=None, arg=None):
    if decomp_id is None:
        decomp_id = row["Sentence.ID"].tolist()[0]
        arg = row["Arg.Phrase"].tolist()[0].lower()
    
    s, c_id = decomp_id.split(" ")
    c_id = int(c_id) - 1
    s = s.split("-")[-1]
    sent = s1_sentences[s][c_id]

    # get the ud2 index from the ud1 index
    mapped_id = alignments[s][0][c_id]
    c_sent = conlls_2[s][mapped_id]
    
    arg = arg.replace("&#39;s", "'s").replace("&quot;", '"').replace("&#39;", "'")
    if arg not in sent.lower():
        print(f"Warning: arg ({arg}) not in sentence ({sent.lower()}) for id {decomp_id}")
    
    tree = get_tree(c_sent.id)
    spacy_parse = spacy_parses[s][c_id]
    return tree, sent, spacy_parse

# %%
roles_wide = roles_ud.pivot_table(index=["Sentence.ID",  "Pred.Lemma", "Arg.Phrase", "Pred.Token", "Arg.Tokens.Begin", "Arg.Tokens.End", "Gram.Func", "Split", "Sent.Grammatical", "Annotator.ID"], columns="Property", values=["Response", "Applicable"], aggfunc=np.mean).reset_index()

roles_wide[["tree", "sentence", "spacy_parse"]] = roles_wide.apply(
    get_sentence_parse, axis=1, result_type='expand')

roles_wide.head()
# Out:
# /var/folders/lq/kd3wh6952vg99n5ppf4srz9w0000gn/T/ipykernel_32876/1214962991.py:1: FutureWarning: The provided callable <function mean at 0x107cb5bc0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   roles_wide = roles_ud.pivot_table(index=["Sentence.ID",  "Pred.Lemma", "Arg.Phrase", "Pred.Token", "Arg.Tokens.Begin", "Arg.Tokens.End", "Gram.Func", "Split", "Sent.Grammatical", "Annotator.ID"], columns="Property", values=["Response", "Applicable"], aggfunc=np.mean).reset_index()
# Warning: child ((IN in)) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((NP (DT the) (NN past))) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((IN in)) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((NP (DT the) (NN past))) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((IN in)) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((NP (DT the) (NN past))) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((IN in)) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((NP (DT the) (NN past))) already has a parent ((PP-TMP (IN in) (NP (DT the) (NN past))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((VP (VBP hope))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP hope))))
# Warning: child ((IN if)) already has a parent ((SBAR-ADV-UNF (IN if)))
# Warning: child ((IN if)) already has a parent ((SBAR-ADV-UNF (IN if)))
# Warning: child ((IN if)) already has a parent ((SBAR-ADV-UNF (IN if)))
# Warning: child ((IN if)) already has a parent ((SBAR-ADV-UNF (IN if)))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((NP-SBJ (PRP he))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))) already has a parent ((S (NP-SBJ (PRP he)) (VP (VBZ 's) (VP (VBN got) (NP-UNF (DT a))))))
# Warning: child ((RB well)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((JJ worth)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((NP (PRP it))) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((RB well)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((JJ worth)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((NP (PRP it))) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((RB well)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((JJ worth)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((NP (PRP it))) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((RB well)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((JJ worth)) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((NP (PRP it))) already has a parent ((ADJP (RB well) (JJ worth) (NP (PRP it))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((RB Just)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((IN for)) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((NP (NNP Fun))) already has a parent ((PP (RB Just) (IN for) (NP (NNP Fun))))
# Warning: child ((JJR more)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((IN than)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((CD 200)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((JJR more)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((IN than)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((CD 200)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((JJR more)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((IN than)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((CD 200)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((JJR more)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((IN than)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((CD 200)) already has a parent ((QP (JJR more) (IN than) (CD 200)))
# Warning: child ((VBD followed)) already has a parent ((VP (VBD followed)))
# Warning: child ((VBD followed)) already has a parent ((VP (VBD followed)))
# Warning: child ((VBD followed)) already has a parent ((VP (VBD followed)))
# Warning: child ((VBD followed)) already has a parent ((VP (VBD followed)))
# Warning: child ((IN at)) already has a parent ((FRAG (IN at)))
# Warning: child ((IN at)) already has a parent ((FRAG (IN at)))
# Warning: child ((IN at)) already has a parent ((FRAG (IN at)))
# Warning: child ((IN at)) already has a parent ((FRAG (IN at)))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (TO to) (VP (VB be) (ADJP-PRD (JJ specific))))))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((CD one)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((HYPH -)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((NN quarter)) already has a parent ((QP (RB about) (CD one) (HYPH -) (NN quarter)))
# Warning: child ((JJ national)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS guards)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((CC or)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS others)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((JJ national)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS guards)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((CC or)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS others)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((JJ national)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS guards)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((CC or)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS others)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((JJ national)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS guards)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((CC or)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((NNS others)) already has a parent ((NP (JJ national) (NNS guards) (CC or) (NNS others)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB out)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((RB there)) already has a parent ((ADVP (RB out) (RB there)))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((VP (VBP Move))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP Move))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((IN off)) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((NP (NN road))) already has a parent ((PP (IN off) (NP (NN road))))
# Warning: child ((CD 2.5)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD million)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD 2.5)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD million)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD 2.5)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD million)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD 2.5)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((CD million)) already has a parent ((QP (CD 2.5) (SYM +) (CD million)))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((IN Into)) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (NN TVA))) already has a parent ((PP (IN Into) (NP (NN TVA))))
# Warning: child ((NP (DT a) (NN lot))) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((JJR more)) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((NP (DT a) (NN lot))) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((JJR more)) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((NP (DT a) (NN lot))) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((JJR more)) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((NP (DT a) (NN lot))) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((JJR more)) already has a parent ((ADJP (NP (DT a) (NN lot)) (JJR more)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# My family loves coming to Endo Sushi . They are very nice , it is never crowded , and the food is wonderful , very delicious and fresh !
# My family loves coming to Endo Sushi . They are very nice , it is never crowded , and the food is wonderful , very delicious and fresh !
# Warning: child ((NP-SBJ (PRP i))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP i))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP i))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP i))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP i)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((IN out)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((HYPH -)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((PP (IN of) (HYPH -) (NP (NN town)))) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((IN out)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((HYPH -)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((PP (IN of) (HYPH -) (NP (NN town)))) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((IN out)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((HYPH -)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((PP (IN of) (HYPH -) (NP (NN town)))) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((IN out)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((HYPH -)) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((PP (IN of) (HYPH -) (NP (NN town)))) already has a parent ((PP (IN out) (HYPH -) (PP (IN of) (HYPH -) (NP (NN town)))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((NP-SBJ (PRP I))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((VP (VBP mean))) already has a parent ((S (NP-SBJ (PRP I)) (VP (VBP mean))))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (NN half)))
# Warning: child ((NN half)) already has a parent ((QP (RB about) (NN half)))
# " The Prophet 's guidance , " says *?* Michael Scheuer , an al - Qaeda analyst who *T* recently retired from the CIA and once headed its Bin Laden unit , " was always , Before you attack someone , *PRO* warn them very clearly ... " The anthrax mailings followed the pattern of letters *0* they sent *T* in January 1997 to newspaper branches in Washington , D.C. and New York City , as well as symbolic targets .
# Warning: child ((VP (VBZ says) (VP (-NONE- *?*)))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((NP-SBJ
#   (NP (NNP Michael) (NNP Scheuer))
#   (, ,)
#   (NP
#     (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#     (SBAR
#       (WHNP-1 (WP who))
#       (S
#         (NP-SBJ-1 (-NONE- *T*))
#         (VP
#           (VP
#             (ADVP-TMP (RB recently))
#             (VBD retired)
#             (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#           (CC and)
#           (VP
#             (ADVP-TMP (RB once))
#             (VBD headed)
#             (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((VP (VBZ says) (VP (-NONE- *?*)))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((NP-SBJ
#   (NP (NNP Michael) (NNP Scheuer))
#   (, ,)
#   (NP
#     (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#     (SBAR
#       (WHNP-1 (WP who))
#       (S
#         (NP-SBJ-1 (-NONE- *T*))
#         (VP
#           (VP
#             (ADVP-TMP (RB recently))
#             (VBD retired)
#             (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#           (CC and)
#           (VP
#             (ADVP-TMP (RB once))
#             (VBD headed)
#             (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# " The Prophet 's guidance , " says *?* Michael Scheuer , an al - Qaeda analyst who *T* recently retired from the CIA and once headed its Bin Laden unit , " was always , Before you attack someone , *PRO* warn them very clearly ... " The anthrax mailings followed the pattern of letters *0* they sent *T* in January 1997 to newspaper branches in Washington , D.C. and New York City , as well as symbolic targets .
# Warning: child ((VP (VBZ says) (VP (-NONE- *?*)))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((NP-SBJ
#   (NP (NNP Michael) (NNP Scheuer))
#   (, ,)
#   (NP
#     (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#     (SBAR
#       (WHNP-1 (WP who))
#       (S
#         (NP-SBJ-1 (-NONE- *T*))
#         (VP
#           (VP
#             (ADVP-TMP (RB recently))
#             (VBD retired)
#             (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#           (CC and)
#           (VP
#             (ADVP-TMP (RB once))
#             (VBD headed)
#             (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((VP (VBZ says) (VP (-NONE- *?*)))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((NP-SBJ
#   (NP (NNP Michael) (NNP Scheuer))
#   (, ,)
#   (NP
#     (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#     (SBAR
#       (WHNP-1 (WP who))
#       (S
#         (NP-SBJ-1 (-NONE- *T*))
#         (VP
#           (VP
#             (ADVP-TMP (RB recently))
#             (VBD retired)
#             (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#           (CC and)
#           (VP
#             (ADVP-TMP (RB once))
#             (VBD headed)
#             (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))) already has a parent ((SINV
#   (VP (VBZ says) (VP (-NONE- *?*)))
#   (NP-SBJ
#     (NP (NNP Michael) (NNP Scheuer))
#     (, ,)
#     (NP
#       (NP (DT an) (NML (NNP al) (HYPH -) (NNP Qaeda)) (NN analyst))
#       (SBAR
#         (WHNP-1 (WP who))
#         (S
#           (NP-SBJ-1 (-NONE- *T*))
#           (VP
#             (VP
#               (ADVP-TMP (RB recently))
#               (VBD retired)
#               (PP-CLR (IN from) (NP (DT the) (NNP CIA))))
#             (CC and)
#             (VP
#               (ADVP-TMP (RB once))
#               (VBD headed)
#               (NP (PRP$ its) (NML (NNP Bin) (NNP Laden)) (NN unit))))))))))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((PRP$ your)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((JJ political)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((NN persuasion)) already has a parent ((NP (PRP$ your) (JJ political) (NN persuasion)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 75)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((SYM -)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 80)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((NN k)) already has a parent ((QP (CD 75) (SYM -) (CD 80) (NN k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 65)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((SYM +)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD 10)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((CD k)) already has a parent ((QP (CD 65) (CD k) (SYM +) (CD 10) (CD k)))
# Warning: child ((ADVP-TMP (RB sometimes))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((NP (NP (PRP mine)) (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((ADVP-TMP (RB sometimes))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((NP (NP (PRP mine)) (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((ADVP-TMP (RB sometimes))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((NP (NP (PRP mine)) (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# Warning: child ((ADVP-TMP (RB sometimes))) already has a parent ((FRAG
#   (ADVP-TMP (RB sometimes))
#   (NP
#     (NP (PRP mine))
#     (PP (IN vs.) (NP (PRP$ my) (NN wife) (POS 's))))))
# ...
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S-IMP (NP-SBJ (-NONE- *PRO*)) (VP (VB take) (ADVP-DIR (RB home)))))
# Warning: child ((VP (VB take) (ADVP-DIR (RB home)))) already has a parent ((S-IMP (NP-SBJ (-NONE- *PRO*)) (VP (VB take) (ADVP-DIR (RB home)))))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((JJ possible)) already has a parent ((ADJP (JJ possible)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((CD 800)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((CD 800)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((CD 800)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((RB about)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((CD 800)) already has a parent ((QP (RB about) (CD 800)))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VBG sniffing) (PP-LOC (IN under) (NP (DT the) (NN door))))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((VP (VB Clear) (CC and) (VB Defend))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Clear) (CC and) (VB Defend))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VP (VB Search) (CC and) (VB Destroy))) already has a parent ((S (NP-SBJ (-NONE- *PRO*)) (VP (VB Search) (CC and) (VB Destroy))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((VB do)) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((NP (NNS tricks))) already has a parent ((VP (VB do) (NP (NNS tricks))))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((JJ false)) already has a parent ((ADJP (JJ false)))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((NP-SBJ (-NONE- *PRO*))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
# Warning: child ((VP (VB Spill) (NP (DT The) (NNP Whisky)))) already has a parent ((S
#   (NP-SBJ (-NONE- *PRO*))
#   (VP (VB Spill) (NP (DT The) (NNP Whisky)))))
#                    Sentence.ID Pred.Lemma  Arg.Phrase Pred.Token  \
# Property
# 0           en-ud-dev.conllu 1       come  this story          3
# 1           en-ud-dev.conllu 1       come  this story          3
# 2         en-ud-dev.conllu 100        cry     america          1
# 3         en-ud-dev.conllu 100        cry     america          1
# 4         en-ud-dev.conllu 100        cry        wolf          1
#
#          Arg.Tokens.Begin Arg.Tokens.End Gram.Func Split Sent.Grammatical  \
# Property
# 0                       4              5     nsubj   dev              5.0
# 1                       4              5     nsubj   dev              5.0
# 2                       0              0     nsubj   dev              2.0
# 3                       0              0     nsubj   dev              5.0
# 4                       2              2      dobj   dev              5.0
#
#          Annotator.ID  ...       Response                                 \
# Property               ... existed_during instigation partitive sentient
# 0                   7  ...            4.0         2.0       2.0      2.0
# 1                  20  ...            5.0         5.0       2.0      1.0
# 2                  46  ...            5.0         5.0       5.0      5.0
# 3                  15  ...            5.0         5.0       5.0      5.0
# 4                  26  ...            3.0         3.0       3.0      1.0
#
#                                             \
# Property volition was_for_benefit was_used
# 0             1.0             2.0      1.0
# 1             3.0             3.0      5.0
# 2             5.0             5.0      5.0
# 3             5.0             3.0      5.0
# 4             3.0             3.0      3.0
#
#                                                        tree  \
# Property
# 0         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 1         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 2         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 3         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 4         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
#
#                                                    sentence  \
# Property
# 0                            From the AP comes this story :
# 1                            From the AP comes this story :
# 2         America cried wolf in Iraq , and what 's scary...
# 3         America cried wolf in Iraq , and what 's scary...
# 4         America cried wolf in Iraq , and what 's scary...
#
#                                                 spacy_parse
# Property
# 0                    (From, the, AP, comes, this, story, :)
# 1                    (From, the, AP, comes, this, story, :)
# 2         (America, cried, wolf, in, Iraq, ,, and, what,...
# 3         (America, cried, wolf, in, Iraq, ,, and, what,...
# 4         (America, cried, wolf, in, Iraq, ,, and, what,...
#
# [5 rows x 41 columns]

# %%
def reduce_traces(terminals, num_tokens):
    n = 0
    i = 0
    while n != num_tokens:
        if terminals[i] != "-NONE-":
            n += 1
        i += 1
    return i

def get_arg(row):
    tree = row["tree"].tolist()[0]
    pred_token =  int(row["Pred.Token"].tolist()[0])
    start = int(row["Arg.Tokens.Begin"].tolist()[0])
    end = int(row["Arg.Tokens.End"].tolist()[0])
    arg = row["Arg.Phrase"].tolist()[0].lower()
    decomp_id = row["Sentence.ID"].tolist()[0]

    # predicate is inside of the argument, so drop
    if start <= pred_token and pred_token <= end:
        return np.nan

    # filter out any traces in the leaves
    leaves, terminals = zip(*tree.pos())
    inc_start = reduce_traces(terminals, start + 1)
    inc_end = reduce_traces(terminals, end + 1)

    indexed_arg = leaves[inc_start - 1: inc_end]
    indexed_arg = " ".join(
        list(filter(lambda x: "*" not in x,
                          indexed_arg))
                          ).replace("-LRB-", "(").replace("-RRB-", ")").lower()
    arg = arg.replace("&#39;s", "'s").replace("&quot;", '"').replace("&#39;", "'")
    if indexed_arg != arg:
        print(f"Warning: arg ({arg}) != indexed_arg ({indexed_arg}) in id ({decomp_id})")

    treepos = tree.treeposition_spanning_leaves(inc_start - 1, inc_end)
    subtree = tree[treepos]

    # leaf, so return immediate parent
    if isinstance(subtree, str):
        treepos = treepos[:-1]
        subtree = tree[treepos]

    # argument is not a syntactic constituent, so drop
    if (len(subtree.leaves()) != (inc_end - inc_start + 1) and \
          "*" not in subtree.leaves()[-1]) or subtree.label() == "VP" :
        print()
        print(inc_end - inc_start)
        print(subtree.leaves())
        print(leaves[inc_start - 1: inc_end])
        print(arg)
        return np.nan

    return subtree, treepos
    
get_arg(roles_wide.iloc[0])
# Out:
# (ParentedTree('NP-SBJ', [ParentedTree('DT', ['this']), ParentedTree('NN', ['story'])]),
#  (2,))

# %%
roles_wide["Arg.Tree_treepos"] = roles_wide.apply(get_arg, axis=1)
print(len(roles_wide))
roles_wide = roles_wide.dropna().reset_index(drop=True)
print(len(roles_wide))

roles_wide["Arg.Tree"] = roles_wide["Arg.Tree_treepos"].apply(lambda x: x[0])
roles_wide["Arg.treepos"] = roles_wide["Arg.Tree_treepos"].apply(lambda x: x[1])
roles_wide.drop(columns=["Arg.Tree_treepos"], inplace=True)

roles_wide.head()
# Out:
# 9
# ['They', 'have', 'fresh', 'flowers', ',', 'lasted', 'a', 'long', 'while', 'in', 'the', 'vase', ',', 'and', 'the', 'two', 'ladies', 'at', 'the', 'shop', 'know', 'the', 'business', 'well', '.']
# ('fresh', 'flowers', ',', 'lasted', 'a', 'long', 'while', 'in', 'the', 'vase')
# fresh flowers , lasted a long while in the vase
#
# 9
# ['They', 'have', 'fresh', 'flowers', ',', 'lasted', 'a', 'long', 'while', 'in', 'the', 'vase', ',', 'and', 'the', 'two', 'ladies', 'at', 'the', 'shop', 'know', 'the', 'business', 'well', '.']
# ('fresh', 'flowers', ',', 'lasted', 'a', 'long', 'while', 'in', 'the', 'vase')
# fresh flowers , lasted a long while in the vase
#
# 29
# ['received', 'an', 'extremely', 'uplifting', 'Christmas', 'present', 'this', 'year', ':', 'an', 'airplane', 'ride', 'just', 'for', 'him', ',', 'courtesy', 'of', 'the', 'International', 'Fund', 'for', 'Animal', 'Welfare', 'and', 'their', 'friends', "'", 'The', 'Bateleurs', "'"]
# ('an', 'extremely', 'uplifting', 'Christmas', 'present', 'this', 'year', ':', 'an', 'airplane', 'ride', 'just', 'for', 'him', ',', 'courtesy', 'of', 'the', 'International', 'Fund', 'for', 'Animal', 'Welfare', 'and', 'their', 'friends', "'", 'The', 'Bateleurs', "'")
# an extremely uplifting christmas present this year : an airplane ride just for him , courtesy of the international fund for animal welfare and their friends ' the bateleurs '
#
# 29
# ['received', 'an', 'extremely', 'uplifting', 'Christmas', 'present', 'this', 'year', ':', 'an', 'airplane', 'ride', 'just', 'for', 'him', ',', 'courtesy', 'of', 'the', 'International', 'Fund', 'for', 'Animal', 'Welfare', 'and', 'their', 'friends', "'", 'The', 'Bateleurs', "'"]
# ('an', 'extremely', 'uplifting', 'Christmas', 'present', 'this', 'year', ':', 'an', 'airplane', 'ride', 'just', 'for', 'him', ',', 'courtesy', 'of', 'the', 'International', 'Fund', 'for', 'Animal', 'Welfare', 'and', 'their', 'friends', "'", 'The', 'Bateleurs', "'")
# an extremely uplifting christmas present this year : an airplane ride just for him , courtesy of the international fund for animal welfare and their friends ' the bateleurs '
#
# 18
# ['From', 'the', 'delectable', 'Antipasto', 'Misto', 'to', 'the', 'Spaghetti', 'alla', 'Barese', 'and', 'the', 'Parmigiana', 'and', 'ending', 'with', 'gelato', ',', 'all', 'was', 'mouth', 'watering', '.']
# ('From', 'the', 'delectable', 'Antipasto', 'Misto', 'to', 'the', 'Spaghetti', 'alla', 'Barese', 'and', 'the', 'Parmigiana', 'and', 'ending', 'with', 'gelato', ',', 'all')
# from the delectable antipasto misto to the spaghetti alla barese and the parmigiana and ending with gelato , all
#
# 18
# ['From', 'the', 'delectable', 'Antipasto', 'Misto', 'to', 'the', 'Spaghetti', 'alla', 'Barese', 'and', 'the', 'Parmigiana', 'and', 'ending', 'with', 'gelato', ',', 'all', 'was', 'mouth', 'watering', '.']
# ('From', 'the', 'delectable', 'Antipasto', 'Misto', 'to', 'the', 'Spaghetti', 'alla', 'Barese', 'and', 'the', 'Parmigiana', 'and', 'ending', 'with', 'gelato', ',', 'all')
# from the delectable antipasto misto to the spaghetti alla barese and the parmigiana and ending with gelato , all
#
# 7
# ['5', 'kg', 'per', 'gun', ',', '200,000', 'guns', 'means', '1000', 'tonnes', ',', 'impossible', 'for', '4', 'containers', '.']
# ('1000', 'tonnes', ',', 'impossible', 'for', '4', 'containers', '.')
# 1000 tonnes , impossible for 4 containers .
#
# 7
# ['5', 'kg', 'per', 'gun', ',', '200,000', 'guns', 'means', '1000', 'tonnes', ',', 'impossible', 'for', '4', 'containers', '.']
# ('1000', 'tonnes', ',', 'impossible', 'for', '4', 'containers', '.')
# 1000 tonnes , impossible for 4 containers .
#
# 9
# ['my', 'initial', 'selection', 'satisfactory', 'but', 'the', 'wine', 'flight', 'we', 'chose', 'to', 'be', 'poorly', 'composed']
# ('my', 'initial', 'selection', 'satisfactory', 'but', 'the', 'wine', 'flight', 'we', 'chose')
# my initial selection satisfactory but the wine flight we chose
#
# 9
# ['my', 'initial', 'selection', 'satisfactory', 'but', 'the', 'wine', 'flight', 'we', 'chose', 'to', 'be', 'poorly', 'composed']
# ('my', 'initial', 'selection', 'satisfactory', 'but', 'the', 'wine', 'flight', 'we', 'chose')
# my initial selection satisfactory but the wine flight we chose
#
# 11
# ['These', '22', 'countries', ',', 'with', 'all', 'their', 'oil', 'and', 'natural', 'resources', ',', 'have', 'a', 'combined', 'GDP', 'smaller', 'than', 'that', 'of', 'Netherlands', 'plus', 'Belgium', 'and', 'equal', 'to', 'half', 'of', 'the', 'GDP', 'of', 'California', 'alone', '.']
# ('These', '22', 'countries', ',', 'with', 'all', 'their', 'oil', 'and', 'natural', 'resources', ',')
# these 22 countries , with all their oil and natural resources ,
#
# 11
# ['These', '22', 'countries', ',', 'with', 'all', 'their', 'oil', 'and', 'natural', 'resources', ',', 'have', 'a', 'combined', 'GDP', 'smaller', 'than', 'that', 'of', 'Netherlands', 'plus', 'Belgium', 'and', 'equal', 'to', 'half', 'of', 'the', 'GDP', 'of', 'California', 'alone', '.']
# ('These', '22', 'countries', ',', 'with', 'all', 'their', 'oil', 'and', 'natural', 'resources', ',')
# these 22 countries , with all their oil and natural resources ,
#
# 2
# ['paid', '2', 'k', 'cash', 'for', 'a', 'truck', 'with', 'a', 'blown', 'motor']
# ('2', 'k', 'cash')
# 2 k cash
#
# 2
# ['paid', '2', 'k', 'cash', 'for', 'a', 'truck', 'with', 'a', 'blown', 'motor']
# ('2', 'k', 'cash')
# 2 k cash
#
# 29
# ['had', 'relatively', 'good', 'facilities', 'at', 'the', 'time', '--', 'decent', 'science', 'labs', ',', 'with', 'multiple', 'hoods', 'and', 'access', 'to', 'good', 'equipment', ';', 'nice', 'gymnasiums', ',', 'and', 'a', 'well', '-', 'funded', 'music', 'department']
# ('relatively', 'good', 'facilities', 'at', 'the', 'time', '--', 'decent', 'science', 'labs', ',', 'with', 'multiple', 'hoods', 'and', 'access', 'to', 'good', 'equipment', ';', 'nice', 'gymnasiums', ',', 'and', 'a', 'well', '-', 'funded', 'music', 'department')
# relatively good facilities at the time -- decent science labs , with multiple hoods and access to good equipment ; nice gymnasiums , and a well - funded music department
#
# 29
# ['had', 'relatively', 'good', 'facilities', 'at', 'the', 'time', '--', 'decent', 'science', 'labs', ',', 'with', 'multiple', 'hoods', 'and', 'access', 'to', 'good', 'equipment', ';', 'nice', 'gymnasiums', ',', 'and', 'a', 'well', '-', 'funded', 'music', 'department']
# ('relatively', 'good', 'facilities', 'at', 'the', 'time', '--', 'decent', 'science', 'labs', ',', 'with', 'multiple', 'hoods', 'and', 'access', 'to', 'good', 'equipment', ';', 'nice', 'gymnasiums', ',', 'and', 'a', 'well', '-', 'funded', 'music', 'department')
# relatively good facilities at the time -- decent science labs , with multiple hoods and access to good equipment ; nice gymnasiums , and a well - funded music department
#
# 6
# ['worked', '30', '%', 'of', 'the', 'time', 'at', 'best']
# ('30', '%', 'of', 'the', 'time', 'at', 'best')
# 30 % of the time at best
#
# 6
# ['worked', '30', '%', 'of', 'the', 'time', 'at', 'best']
# ('30', '%', 'of', 'the', 'time', 'at', 'best')
# 30 % of the time at best
#
# 23
# ['It', 'is', 'this', 'circle', 'that', 'makes', 'sure', 'that', 'women', 'remain', 'inferior', ',', 'that', 'democracy', 'is', 'unthinkable', 'and', 'that', 'exposure', 'to', 'the', 'outside', 'world', 'is', 'minimal', '.']
# ('this', 'circle', 'that', 'makes', 'sure', 'that', 'women', 'remain', 'inferior', ',', 'that', 'democracy', 'is', 'unthinkable', 'and', 'that', 'exposure', 'to', 'the', 'outside', 'world', 'is', 'minimal', '.')
# this circle that makes sure that women remain inferior , that democracy is unthinkable and that exposure to the outside world is minimal .
#
# 23
# ['It', 'is', 'this', 'circle', 'that', 'makes', 'sure', 'that', 'women', 'remain', 'inferior', ',', 'that', 'democracy', 'is', 'unthinkable', 'and', 'that', 'exposure', 'to', 'the', 'outside', 'world', 'is', 'minimal', '.']
# ('this', 'circle', 'that', 'makes', 'sure', 'that', 'women', 'remain', 'inferior', ',', 'that', 'democracy', 'is', 'unthinkable', 'and', 'that', 'exposure', 'to', 'the', 'outside', 'world', 'is', 'minimal', '.')
# this circle that makes sure that women remain inferior , that democracy is unthinkable and that exposure to the outside world is minimal .
#
# 32
# ['held', 'elections', 'in', 'October', 'of', '2002', ',', 'in', 'which', 'center', '-', 'right', 'parties', 'did', 'well', ',', 'but', 'in', 'which', 'nearly', '20', 'percent', 'of', 'parliament', 'seats', 'went', 'to', 'the', 'fundamentalist', 'religious', 'party', 'coalition', ',', 'MMA']
# ('elections', 'in', 'October', 'of', '2002', ',', 'in', 'which', 'center', '-', 'right', 'parties', 'did', 'well', ',', 'but', 'in', 'which', 'nearly', '20', 'percent', 'of', 'parliament', 'seats', 'went', 'to', 'the', 'fundamentalist', 'religious', 'party', 'coalition', ',', 'MMA')
# elections in october of 2002 , in which center - right parties did well , but in which nearly 20 percent of parliament seats went to the fundamentalist religious party coalition , mma
#
# 32
# ['held', 'elections', 'in', 'October', 'of', '2002', ',', 'in', 'which', 'center', '-', 'right', 'parties', 'did', 'well', ',', 'but', 'in', 'which', 'nearly', '20', 'percent', 'of', 'parliament', 'seats', 'went', 'to', 'the', 'fundamentalist', 'religious', 'party', 'coalition', ',', 'MMA']
# ('elections', 'in', 'October', 'of', '2002', ',', 'in', 'which', 'center', '-', 'right', 'parties', 'did', 'well', ',', 'but', 'in', 'which', 'nearly', '20', 'percent', 'of', 'parliament', 'seats', 'went', 'to', 'the', 'fundamentalist', 'religious', 'party', 'coalition', ',', 'MMA')
# elections in october of 2002 , in which center - right parties did well , but in which nearly 20 percent of parliament seats went to the fundamentalist religious party coalition , mma
#
# 14
# ['released', 'a', 'statement', 'Friday', 'taking', 'Bush', 'to', 'task', 'for', 'his', 'comments', 'on', 'Pakistan', "'s", 'recent', 'coup']
# ('a', 'statement', 'Friday', 'taking', 'Bush', 'to', 'task', 'for', 'his', 'comments', 'on', 'Pakistan', "'s", 'recent', 'coup')
# a statement friday taking bush to task for his comments on pakistan 's recent coup
#
# 14
# ['released', 'a', 'statement', 'Friday', 'taking', 'Bush', 'to', 'task', 'for', 'his', 'comments', 'on', 'Pakistan', "'s", 'recent', 'coup']
# ('a', 'statement', 'Friday', 'taking', 'Bush', 'to', 'task', 'for', 'his', 'comments', 'on', 'Pakistan', "'s", 'recent', 'coup')
# a statement friday taking bush to task for his comments on pakistan 's recent coup
#
# 19
# ['Attached', 'are', 'the', 'draft', 'Schedule', 'to', 'the', 'ISDA', 'Master', 'Agreement', ',', 'together', 'with', 'Paragraph', '13', 'to', 'the', 'ISDA', 'Credit', 'Support', 'Annex', '.']
# ('the', 'draft', 'Schedule', 'to', 'the', 'ISDA', 'Master', 'Agreement', ',', 'together', 'with', 'Paragraph', '13', 'to', 'the', 'ISDA', 'Credit', 'Support', 'Annex', '.')
# the draft schedule to the isda master agreement , together with paragraph 13 to the isda credit support annex .
#
# 19
# ['Attached', 'are', 'the', 'draft', 'Schedule', 'to', 'the', 'ISDA', 'Master', 'Agreement', ',', 'together', 'with', 'Paragraph', '13', 'to', 'the', 'ISDA', 'Credit', 'Support', 'Annex', '.']
# ('the', 'draft', 'Schedule', 'to', 'the', 'ISDA', 'Master', 'Agreement', ',', 'together', 'with', 'Paragraph', '13', 'to', 'the', 'ISDA', 'Credit', 'Support', 'Annex', '.')
# the draft schedule to the isda master agreement , together with paragraph 13 to the isda credit support annex .
#
# 7
# ["'s", 'a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK']
# ('a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK')
# a new eol counterparty listed in the uk
#
# 7
# ["'s", 'a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK']
# ('a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK')
# a new eol counterparty listed in the uk
#
# 7
# ["'s", 'a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK']
# ('a', 'new', 'EOL', 'Counterparty', 'listed', 'in', 'the', 'UK')
# a new eol counterparty listed in the uk
#
# 7
# ['Maintains', 'the', 'basic', 'Gas', 'Accord', 'structure', 'in', 'place', 'today', 'for', 'the', 'period', '2003', 'to', '2007']
# ('the', 'basic', 'Gas', 'Accord', 'structure', 'in', 'place', 'today')
# the basic gas accord structure in place today
#
# 7
# ['Maintains', 'the', 'basic', 'Gas', 'Accord', 'structure', 'in', 'place', 'today', 'for', 'the', 'period', '2003', 'to', '2007']
# ('the', 'basic', 'Gas', 'Accord', 'structure', 'in', 'place', 'today')
# the basic gas accord structure in place today
#
# 55
# ['signed', 'a', 'declaration', 'on', 'February', '3rd', ',', '1983', ',', 'that', 'on', 'November', '8th', ',', '1982', ',', 'he', 'had', 'authorized', 'a', 'search', 'of', 'CIA', 'records', '"', 'for', 'any', 'material', 'that', 'in', 'any', 'way', 'pertains', 'to', 'Edwin', 'P.', 'Wilson', ',', 'or', 'the', 'various', 'allegations', 'concerning', 'his', 'activities', 'after', 'February', '28th', ',', '1971', ',', 'when', 'he', 'retired', 'from', 'the', 'CIA']
# ('a', 'declaration', 'on', 'February', '3rd', ',', '1983', ',', 'that', 'on', 'November', '8th', ',', '1982', ',', 'he', 'had', 'authorized', 'a', 'search', 'of', 'CIA', 'records', '"', 'for', 'any', 'material', 'that', 'in', 'any', 'way', 'pertains', 'to', 'Edwin', 'P.', 'Wilson', ',', 'or', 'the', 'various', 'allegations', 'concerning', 'his', 'activities', 'after', 'February', '28th', ',', '1971', ',', 'when', 'he', 'retired', 'from', 'the', 'CIA')
# a declaration on february 3rd , 1983 , that on november 8th , 1982 , he had authorized a search of cia records " for any material that in any way pertains to edwin p. wilson , or the various allegations concerning his activities after february 28th , 1971 , when he retired from the cia
#
# 55
# ['signed', 'a', 'declaration', 'on', 'February', '3rd', ',', '1983', ',', 'that', 'on', 'November', '8th', ',', '1982', ',', 'he', 'had', 'authorized', 'a', 'search', 'of', 'CIA', 'records', '"', 'for', 'any', 'material', 'that', 'in', 'any', 'way', 'pertains', 'to', 'Edwin', 'P.', 'Wilson', ',', 'or', 'the', 'various', 'allegations', 'concerning', 'his', 'activities', 'after', 'February', '28th', ',', '1971', ',', 'when', 'he', 'retired', 'from', 'the', 'CIA']
# ('a', 'declaration', 'on', 'February', '3rd', ',', '1983', ',', 'that', 'on', 'November', '8th', ',', '1982', ',', 'he', 'had', 'authorized', 'a', 'search', 'of', 'CIA', 'records', '"', 'for', 'any', 'material', 'that', 'in', 'any', 'way', 'pertains', 'to', 'Edwin', 'P.', 'Wilson', ',', 'or', 'the', 'various', 'allegations', 'concerning', 'his', 'activities', 'after', 'February', '28th', ',', '1971', ',', 'when', 'he', 'retired', 'from', 'the', 'CIA')
# a declaration on february 3rd , 1983 , that on november 8th , 1982 , he had authorized a search of cia records " for any material that in any way pertains to edwin p. wilson , or the various allegations concerning his activities after february 28th , 1971 , when he retired from the cia
#
# 17
# ['It', 'is', 'our', 'belief', 'that', 'this', 'compensation', 'plan', 'will', 'produce', 'some', 'of', 'the', 'largest', 'checks', 'in', 'network', 'marketing', 'history', '.']
# ('our', 'belief', 'that', 'this', 'compensation', 'plan', 'will', 'produce', 'some', 'of', 'the', 'largest', 'checks', 'in', 'network', 'marketing', 'history', '.')
# our belief that this compensation plan will produce some of the largest checks in network marketing history .
#
# 17
# ['It', 'is', 'our', 'belief', 'that', 'this', 'compensation', 'plan', 'will', 'produce', 'some', 'of', 'the', 'largest', 'checks', 'in', 'network', 'marketing', 'history', '.']
# ('our', 'belief', 'that', 'this', 'compensation', 'plan', 'will', 'produce', 'some', 'of', 'the', 'largest', 'checks', 'in', 'network', 'marketing', 'history', '.')
# our belief that this compensation plan will produce some of the largest checks in network marketing history .
#
# 16
# ['oppose', 'the', 'use', 'of', 'sacred', 'texts', 'and', 'religious', 'traditions', 'to', 'deny', 'legal', 'equity', 'to', 'same', '-', 'gender', 'couples']
# ('the', 'use', 'of', 'sacred', 'texts', 'and', 'religious', 'traditions', 'to', 'deny', 'legal', 'equity', 'to', 'same', '-', 'gender', 'couples')
# the use of sacred texts and religious traditions to deny legal equity to same - gender couples
#
# 16
# ['oppose', 'the', 'use', 'of', 'sacred', 'texts', 'and', 'religious', 'traditions', 'to', 'deny', 'legal', 'equity', 'to', 'same', '-', 'gender', 'couples']
# ('the', 'use', 'of', 'sacred', 'texts', 'and', 'religious', 'traditions', 'to', 'deny', 'legal', 'equity', 'to', 'same', '-', 'gender', 'couples')
# the use of sacred texts and religious traditions to deny legal equity to same - gender couples
#
# 6
# ['take', 'the', 'one', 'that', 'in', 'not', 'very', 'interested']
# ('the', 'one', 'that', 'in', 'not', 'very', 'interested')
# the one that in not very interested
#
# 6
# ['take', 'the', 'one', 'that', 'in', 'not', 'very', 'interested']
# ('the', 'one', 'that', 'in', 'not', 'very', 'interested')
# the one that in not very interested
#
# 10
# ['had', 'a', 'larger', 'black', 'population', 'in', 'the', '70s', 'than', 'we', 'have', 'now']
# ('a', 'larger', 'black', 'population', 'in', 'the', '70s', 'than', 'we', 'have', 'now')
# a larger black population in the 70s than we have now
#
# 10
# ['had', 'a', 'larger', 'black', 'population', 'in', 'the', '70s', 'than', 'we', 'have', 'now']
# ('a', 'larger', 'black', 'population', 'in', 'the', '70s', 'than', 'we', 'have', 'now')
# a larger black population in the 70s than we have now
#
# 14
# ['is', 'the', 'marrying', 'off', 'of', 'young', 'girls', 'to', 'older', 'men', 'often', 'close', 'relatives', 'that', 'enfurates', 'me']
# ('the', 'marrying', 'off', 'of', 'young', 'girls', 'to', 'older', 'men', 'often', 'close', 'relatives', 'that', 'enfurates', 'me')
# the marrying off of young girls to older men often close relatives that enfurates me
#
# 14
# ['is', 'the', 'marrying', 'off', 'of', 'young', 'girls', 'to', 'older', 'men', 'often', 'close', 'relatives', 'that', 'enfurates', 'me']
# ('the', 'marrying', 'off', 'of', 'young', 'girls', 'to', 'older', 'men', 'often', 'close', 'relatives', 'that', 'enfurates', 'me')
# the marrying off of young girls to older men often close relatives that enfurates me
#
# 5
# ['the', 'location', 'wonderful', 'and', 'the', 'neighbors', 'very', 'kind']
# ('the', 'location', 'wonderful', 'and', 'the', 'neighbors')
# the location wonderful and the neighbors
#
# 5
# ['the', 'location', 'wonderful', 'and', 'the', 'neighbors', 'very', 'kind']
# ('the', 'location', 'wonderful', 'and', 'the', 'neighbors')
# the location wonderful and the neighbors
# 7570
# 7499
# /var/folders/lq/kd3wh6952vg99n5ppf4srz9w0000gn/T/ipykernel_32876/1834590317.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   roles_wide.drop(columns=["Arg.Tree_treepos"], inplace=True)
#                    Sentence.ID Pred.Lemma  Arg.Phrase Pred.Token  \
# Property
# 0           en-ud-dev.conllu 1       come  this story          3
# 1           en-ud-dev.conllu 1       come  this story          3
# 2         en-ud-dev.conllu 100        cry     america          1
# 3         en-ud-dev.conllu 100        cry     america          1
# 4         en-ud-dev.conllu 100        cry        wolf          1
#
#          Arg.Tokens.Begin Arg.Tokens.End Gram.Func Split Sent.Grammatical  \
# Property
# 0                       4              5     nsubj   dev              5.0
# 1                       4              5     nsubj   dev              5.0
# 2                       0              0     nsubj   dev              2.0
# 3                       0              0     nsubj   dev              5.0
# 4                       2              2      dobj   dev              5.0
#
#          Annotator.ID  ...  Response                                    \
# Property               ... partitive sentient volition was_for_benefit
# 0                   7  ...       2.0      2.0      1.0             2.0
# 1                  20  ...       2.0      1.0      3.0             3.0
# 2                  46  ...       5.0      5.0      5.0             5.0
# 3                  15  ...       5.0      5.0      5.0             3.0
# 4                  26  ...       3.0      1.0      3.0             3.0
#
#                                                                 tree  \
# Property was_used
# 0             1.0  [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 1             5.0  [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 2             5.0  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 3             5.0  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 4             3.0  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
#
#                                                    sentence  \
# Property
# 0                            From the AP comes this story :
# 1                            From the AP comes this story :
# 2         America cried wolf in Iraq , and what 's scary...
# 3         America cried wolf in Iraq , and what 's scary...
# 4         America cried wolf in Iraq , and what 's scary...
#
#                                                 spacy_parse  \
# Property
# 0                    (From, the, AP, comes, this, story, :)
# 1                    (From, the, AP, comes, this, story, :)
# 2         (America, cried, wolf, in, Iraq, ,, and, what,...
# 3         (America, cried, wolf, in, Iraq, ,, and, what,...
# 4         (America, cried, wolf, in, Iraq, ,, and, what,...
#
#                    Arg.Tree Arg.treepos
# Property
# 0         [[this], [story]]        (2,)
# 1         [[this], [story]]        (2,)
# 2                 [America]      (0, 0)
# 3                 [America]      (0, 0)
# 4                    [wolf]   (0, 1, 1)
#
# [5 rows x 43 columns]

# %%
class Node:
    def __init__(self, name):
        self.name = name
        self.left = []
        self.right = []

    def to_string(self):
        left_string, right_string = "", ""
        if self.left:
            left_string = " ".join(l.to_string() for l in self.left) + " "
        if self.right:
            right_string = " " + " ".join(r.to_string() for r in self.right)
        return left_string + self.name + right_string
    

def filter_children(root):
    children = []
    for child in root.lefts:
        children.append((child, "left"))
    
    for child in root.rights:
        children.append((child, "right"))

    new_arg = Node(root.text)

    for child, side in children:
        # print(child, child.dep_)

        # keep dets
        if child.dep_ == "det":
            if side == "left":
                new_arg.left.append(Node(child.text))
            else:
                new_arg.right.append(Node(child.text))
        elif child.dep_ == "poss" or child.dep_ == "nmod:poss":
            # change poss to det
            if side == "left":
                new_arg.left.append(Node("the"))
            else:
                new_arg.right.append(Node("the"))
        # keep compounds, verbs, det
        elif child.dep_ in ["cc", "compound", "conj", "nummod",
                            "xcomp", "nsubj", "dobj", "mark"] or \
            child.pos_ in ["VERB", "AUX"]:
            if side == "left":
                node = filter_children(child)
                new_arg.left.append(node)
            else:
                node = filter_children(child)
                new_arg.right.append(node)
    
    return new_arg

# %%
def get_stripped(row, remove_all=False):
    if not remove_all:
        dep_parse = row["spacy_parse"].tolist()[0]
        tree = row["tree"].tolist()[0].copy(deep=True)
        arg_treepos = row["Arg.treepos"].tolist()[0]
        subtree = tree[arg_treepos]

        start = row["Arg.Tokens.Begin"].tolist()[0]
        end = row["Arg.Tokens.End"].tolist()[0]

        pred_idx = row["Pred.Token"].tolist()[0]
        predicate = dep_parse[pred_idx].text

        dep_span = dep_parse[start:end + 1]
        arg = dep_span.text
        stripped_arg = filter_children(dep_span.root).to_string()

        if not (isinstance(subtree, str) or "NP" in subtree.label().split("-")[0] or (subtree.parent() and "NP" in subtree.parent().label())):
            print()
            print(subtree.label())
            print(" ".join(subtree.leaves()))
            print(stripped_arg)

        return predicate, arg, stripped_arg, dep_span 
    else:
        raise NotImplemented

# %%
roles_wide[
    ["Predicate", "Arg.Phrase", "Arg.Stripped", "Arg.Parse"]
        ] =  roles_wide.apply(get_stripped, axis=1, result_type='expand')


roles_wide.head()
# Out:
# SBAR-NOM-SBJ
# What you say
# What you say
#
# SBAR-NOM-SBJ
# What you say
# What you say
#
# SBAR-NOM-SBJ
# What they wonder
# What they wonder
#
# SBAR-NOM-SBJ
# What I love most about this place , other than the food
# What I love
#
# SBAR-NOM-SBJ
# What I love most about this place , other than the food
# What I love
#
# S
# us feel secure in our decision to buy when we did
# us feel secure
#
# S
# us feel secure in our decision to buy when we did
# us feel secure
#
# SBAR
# what I wanted and that I previously went to Braman Honda
# what I wanted and that I went
#
# SBAR
# what I wanted and that I previously went to Braman Honda
# what I wanted and that I went
#
# SBAR-NOM-SBJ
# What I like most about Dr. Liau
# What I like
#
# SBAR-NOM-SBJ
# What I like most about Dr. Liau
# What I like
#
# ADJP-PRD+JJR
# bigger
# bigger
#
# ADJP-PRD+JJR
# bigger
# bigger
#
# SBAR-NOM
# WHAT YOU PAY FOR
# WHAT YOU PAY
#
# SBAR-NOM
# WHAT YOU PAY FOR
# WHAT YOU PAY
#
# UCP
# at least this much , in this crisis , to cease militarily unnecessary provocations and establish genuine peace
# much to cease provocations and establish peace
#
# UCP
# at least this much , in this crisis , to cease militarily unnecessary provocations and establish genuine peace
# much to cease provocations and establish peace
#
# S
# a new book out
# a book
#
# S
# a new book out
# a book
#
# INTJ-SEZ+UH
# OK
# OK
#
# INTJ-SEZ+UH
# OK
# OK
#
# SBAR-NOM
# what he thought had to be done at the time to keep the power flowing
# what he thought had to be done to keep the power flowing
#
# SBAR-NOM
# what he thought had to be done at the time to keep the power flowing
# what he thought had to be done to keep the power flowing
#
# SBAR-NOM-SBJ
# What I know
# What I know
#
# SBAR-NOM-SBJ
# What I know
# What I know
#
# SBAR-NOM-SBJ
# What I heard
# What I heard
#
# SBAR-NOM-SBJ
# What I heard
# What I heard
#
# S
# a poor little mouse walking around in my friend s house
# a little mouse walking
#
# S
# a poor little mouse walking around in my friend s house
# a little mouse walking
#
# FRAG-SEZ
# Note : you must meet the minimum requirements for your application to be eligible for processing
# Note you must meet the requirements
#
# FRAG-SEZ
# Note : you must meet the minimum requirements for your application to be eligible for processing
# Note you must meet the requirements
#                    Sentence.ID Pred.Lemma  Arg.Phrase Pred.Token  \
# Property
# 0           en-ud-dev.conllu 1       come  this story          3
# 1           en-ud-dev.conllu 1       come  this story          3
# 2         en-ud-dev.conllu 100        cry     America          1
# 3         en-ud-dev.conllu 100        cry     America          1
# 4         en-ud-dev.conllu 100        cry        wolf          1
#
#          Arg.Tokens.Begin Arg.Tokens.End Gram.Func Split Sent.Grammatical  \
# Property
# 0                       4              5     nsubj   dev              5.0
# 1                       4              5     nsubj   dev              5.0
# 2                       0              0     nsubj   dev              2.0
# 3                       0              0     nsubj   dev              5.0
# 4                       2              2      dobj   dev              5.0
#
#          Annotator.ID  ...        Response           \
# Property               ... was_for_benefit was_used
# 0                   7  ...             2.0      1.0
# 1                  20  ...             3.0      5.0
# 2                  46  ...             5.0      5.0
# 3                  15  ...             3.0      5.0
# 4                  26  ...             3.0      3.0
#
#                                                        tree  \
# Property
# 0         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 1         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 2         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 3         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 4         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
#
#                                                    sentence  \
# Property
# 0                            From the AP comes this story :
# 1                            From the AP comes this story :
# 2         America cried wolf in Iraq , and what 's scary...
# 3         America cried wolf in Iraq , and what 's scary...
# 4         America cried wolf in Iraq , and what 's scary...
#
#                                                 spacy_parse  \
# Property
# 0                    (From, the, AP, comes, this, story, :)
# 1                    (From, the, AP, comes, this, story, :)
# 2         (America, cried, wolf, in, Iraq, ,, and, what,...
# 3         (America, cried, wolf, in, Iraq, ,, and, what,...
# 4         (America, cried, wolf, in, Iraq, ,, and, what,...
#
#                    Arg.Tree Arg.treepos Predicate Arg.Stripped      Arg.Parse
# Property
# 0         [[this], [story]]        (2,)     comes   this story  (this, story)
# 1         [[this], [story]]        (2,)     comes   this story  (this, story)
# 2                 [America]      (0, 0)     cried      America      (America)
# 3                 [America]      (0, 0)     cried      America      (America)
# 4                    [wolf]   (0, 1, 1)     cried         wolf         (wolf)
#
# [5 rows x 46 columns]

# %%
def save_spacy_parse(parse):
    return parse.as_doc().to_json()

roles_wide["spacy_parse"] = roles_wide["spacy_parse"].apply(save_spacy_parse)
roles_wide["Arg.Parse"] = roles_wide["Arg.Parse"].apply(save_spacy_parse)
roles_wide.drop(columns=["Arg.Stripped"]).to_csv("decomp_ud_trees.csv")
# Out:
# /var/folders/lq/kd3wh6952vg99n5ppf4srz9w0000gn/T/ipykernel_32876/525955532.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   roles_wide.drop(columns=["Arg.Stripped"]).to_csv("decomp_ud_trees.csv")

# %%
import conllu

def read_conllu(conll_file, propbank = True):
    data = open(conll_file, encoding="utf-8")
    text = data.read()

    fields = ['id', 'form', 'lemma', 'upos', 'xpos', 'feats', 'head', 'deprel', 'deps', 'misc']
    if propbank:
        fields += ['frame', 'role']

    sentences = conllu.parse(
        text,
        fields = fields
        )
    return sentences

conlls_propbank = {}
conlls = {}

sets = ["train.conllu", "test.conllu", "dev.conllu"]
for s in sets:
    conlls_propbank[s] = read_conllu("UP_English-EWT/en_ewt-up-" + s)
    conlls[s] = read_conllu("../datasets/UD_English/en-ud-" + s, propbank=False)

# %%
def get_roleset(sentence_id, pred_token, lemma):
    dataset, index = sentence_id.split(" ")
    dataset = dataset.split("-")[-1]
    verb = conlls_propbank[dataset][int(index) - 1][pred_token]
    if verb["lemma"] != lemma:
        print(sentence_id, pred_token, lemma, verb)
    if "frame" in verb:
        return verb["frame"]
    else:
        print("warning: missing frame, ", verb)
        return "N/A"

roles_wide["Roleset"] = roles_wide.apply(
                            lambda x: get_roleset(x["Sentence.ID"][0], x["Pred.Token"][0], x["Pred.Lemma"][0]),
                            axis=1
                        )

roles_wide.head()
# Out:
# /var/folders/lq/kd3wh6952vg99n5ppf4srz9w0000gn/T/ipykernel_32876/2758161579.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x: get_roleset(x["Sentence.ID"][0], x["Pred.Token"][0], x["Pred.Lemma"][0]),
# en-ud-dev.conllu 1304 1 se se
# en-ud-dev.conllu 1304 1 se se
# en-ud-train.conllu 10228 2 fixede fixeded
# en-ud-train.conllu 10228 2 fixede fixeded
# en-ud-train.conllu 10228 2 fixede fixeded
# en-ud-train.conllu 10228 2 fixede fixeded
# en-ud-train.conllu 10432 1 reccomend reccomend
# en-ud-train.conllu 10432 1 reccomend reccomend
# en-ud-train.conllu 10432 1 reccomend reccomend
# en-ud-train.conllu 10432 1 reccomend reccomend
# en-ud-train.conllu 11217 4 where where
# en-ud-train.conllu 11217 4 where where
# en-ud-train.conllu 11808 1 thouhgt thouhgt
# en-ud-train.conllu 11808 1 thouhgt thouhgt
# en-ud-train.conllu 12055 1 precede preceded
# en-ud-train.conllu 12055 1 precede preceded
# en-ud-train.conllu 7411 2 wan wan
# en-ud-train.conllu 7411 2 wan wan
# warning: missing frame,  works
# warning: missing frame,  works
#                    Sentence.ID Pred.Lemma  Arg.Phrase Pred.Token  \
# Property
# 0           en-ud-dev.conllu 1       come  this story          3
# 1           en-ud-dev.conllu 1       come  this story          3
# 2         en-ud-dev.conllu 100        cry     America          1
# 3         en-ud-dev.conllu 100        cry     America          1
# 4         en-ud-dev.conllu 100        cry        wolf          1
#
#          Arg.Tokens.Begin Arg.Tokens.End Gram.Func Split Sent.Grammatical  \
# Property
# 0                       4              5     nsubj   dev              5.0
# 1                       4              5     nsubj   dev              5.0
# 2                       0              0     nsubj   dev              2.0
# 3                       0              0     nsubj   dev              5.0
# 4                       2              2      dobj   dev              5.0
#
#          Annotator.ID  ... Response  \
# Property               ... was_used
# 0                   7  ...      1.0
# 1                  20  ...      5.0
# 2                  46  ...      5.0
# 3                  15  ...      5.0
# 4                  26  ...      3.0
#
#                                                        tree  \
# Property
# 0         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 1         [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 2         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 3         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 4         [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
#
#                                                    sentence  \
# Property
# 0                            From the AP comes this story :
# 1                            From the AP comes this story :
# 2         America cried wolf in Iraq , and what 's scary...
# 3         America cried wolf in Iraq , and what 's scary...
# 4         America cried wolf in Iraq , and what 's scary...
#
#                                                 spacy_parse  \
# Property
# 0         {'text': 'From the AP comes this story : ', 's...
# 1         {'text': 'From the AP comes this story : ', 's...
# 2         {'text': 'America cried wolf in Iraq, and what...
# 3         {'text': 'America cried wolf in Iraq, and what...
# 4         {'text': 'America cried wolf in Iraq, and what...
#
#                    Arg.Tree Arg.treepos Predicate Arg.Stripped  \
# Property
# 0         [[this], [story]]        (2,)     comes   this story
# 1         [[this], [story]]        (2,)     comes   this story
# 2                 [America]      (0, 0)     cried      America
# 3                 [America]      (0, 0)     cried      America
# 4                    [wolf]   (0, 1, 1)     cried         wolf
#
#                                                   Arg.Parse  Roleset
# Property
# 0         {'text': 'this story ', 'sents': [{'start': 0,...  come.03
# 1         {'text': 'this story ', 'sents': [{'start': 0,...  come.03
# 2         {'text': 'America ', 'sents': [{'start': 0, 'e...   cry.01
# 3         {'text': 'America ', 'sents': [{'start': 0, 'e...   cry.01
# 4         {'text': 'wolf ', 'sents': [{'start': 0, 'end'...   cry.01
#
# [5 rows x 47 columns]

# %%
def get_arg_nums(sentence_id, arg_start_idx, arg_end_idx):
    dataset, index = sentence_id.split(" ")
    dataset = dataset.split("-")[-1]
    index = int(index) - 1

    # iterate through all tokens in arg to find the role
    for i in range(arg_start_idx, arg_end_idx + 1):
        arg = conlls_propbank[dataset][index][i]

        if "role" in arg and "ARG" in arg["role"]:
            return arg["role"][-1]
        
    print("Warning: could not find ARG role ", sentence_id, arg_start_idx, arg_end_idx)
    return np.nan

roles_wide["Arg"] = roles_wide.apply(
                            lambda x: get_arg_nums(
                                x["Sentence.ID"][0],
                                x["Arg.Tokens.Begin"][0],
                                x["Arg.Tokens.End"][0]),
                            axis=1
                        )
print(roles_wide.shape)
# roles_wide = roles_wide.dropna(subset=[("Arg", "")])
roles_wide.head()
# Out:
# Warning: could not find ARG role  en-ud-dev.conllu 1002 17 19
# Warning: could not find ARG role  en-ud-dev.conllu 1002 17 19
# Warning: could not find ARG role  en-ud-dev.conllu 1013 6 6
# Warning: could not find ARG role  en-ud-dev.conllu 1013 6 6
# Warning: could not find ARG role  en-ud-dev.conllu 1013 8 16
# Warning: could not find ARG role  en-ud-dev.conllu 1013 8 16
# Warning: could not find ARG role  en-ud-dev.conllu 1020 25 32
# Warning: could not find ARG role  en-ud-dev.conllu 1023 23 23
# Warning: could not find ARG role  en-ud-dev.conllu 1023 23 23
# Warning: could not find ARG role  en-ud-dev.conllu 1083 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1083 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1084 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1084 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 117 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 117 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 118 36 36
# Warning: could not find ARG role  en-ud-dev.conllu 118 36 36
# Warning: could not find ARG role  en-ud-dev.conllu 118 38 38
# Warning: could not find ARG role  en-ud-dev.conllu 118 38 38
# Warning: could not find ARG role  en-ud-dev.conllu 1214 2 4
# Warning: could not find ARG role  en-ud-dev.conllu 1214 2 4
# Warning: could not find ARG role  en-ud-dev.conllu 1214 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1214 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 143 4 4
# Warning: could not find ARG role  en-ud-dev.conllu 143 4 4
# Warning: could not find ARG role  en-ud-dev.conllu 143 1 1
# Warning: could not find ARG role  en-ud-dev.conllu 143 1 1
# Warning: could not find ARG role  en-ud-dev.conllu 151 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 151 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 154 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 154 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 155 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 155 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1670 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 1670 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 1701 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 1701 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 1779 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1779 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1798 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1798 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1815 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1815 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1823 10 10
# Warning: could not find ARG role  en-ud-dev.conllu 1823 10 10
# Warning: could not find ARG role  en-ud-dev.conllu 183 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 183 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1844 7 7
# Warning: could not find ARG role  en-ud-dev.conllu 1844 7 7
# Warning: could not find ARG role  en-ud-dev.conllu 1844 9 9
# Warning: could not find ARG role  en-ud-dev.conllu 1844 9 9
# Warning: could not find ARG role  en-ud-dev.conllu 1897 12 12
# Warning: could not find ARG role  en-ud-dev.conllu 1897 12 12
# Warning: could not find ARG role  en-ud-dev.conllu 1905 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1905 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1963 0 2
# Warning: could not find ARG role  en-ud-dev.conllu 1963 0 2
# Warning: could not find ARG role  en-ud-dev.conllu 1973 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 1973 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 199 6 6
# Warning: could not find ARG role  en-ud-dev.conllu 199 6 6
# Warning: could not find ARG role  en-ud-dev.conllu 206 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 206 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 223 22 27
# Warning: could not find ARG role  en-ud-dev.conllu 223 22 27
# Warning: could not find ARG role  en-ud-dev.conllu 225 24 26
# Warning: could not find ARG role  en-ud-dev.conllu 225 24 26
# Warning: could not find ARG role  en-ud-dev.conllu 251 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 251 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 26 4 14
# Warning: could not find ARG role  en-ud-dev.conllu 26 4 14
# Warning: could not find ARG role  en-ud-dev.conllu 270 0 7
# Warning: could not find ARG role  en-ud-dev.conllu 270 0 7
# Warning: could not find ARG role  en-ud-dev.conllu 271 3 4
# Warning: could not find ARG role  en-ud-dev.conllu 271 3 4
# Warning: could not find ARG role  en-ud-dev.conllu 320 0 2
# Warning: could not find ARG role  en-ud-dev.conllu 320 0 2
# Warning: could not find ARG role  en-ud-dev.conllu 323 4 5
# Warning: could not find ARG role  en-ud-dev.conllu 323 4 5
# Warning: could not find ARG role  en-ud-dev.conllu 328 0 30
# Warning: could not find ARG role  en-ud-dev.conllu 328 0 30
# Warning: could not find ARG role  en-ud-dev.conllu 347 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 347 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 379 0 1
# Warning: could not find ARG role  en-ud-dev.conllu 379 0 1
# Warning: could not find ARG role  en-ud-dev.conllu
0 0
# Warning: could not find ARG role  en-ud-dev.conllu 96 0 0
# Warning: could not find ARG role  en-ud-dev.conllu 962 16 21
# Warning: could not find ARG role  en-ud-dev.conllu 962 16 21
# Warning: could not find ARG role  en-ud-dev.conllu 979 25 43
# Warning: could not find ARG role  en-ud-dev.conllu 979 25 43
# Warning: could not find ARG role  en-ud-dev.conllu 98 5 9
# Warning: could not find ARG role  en-ud-dev.conllu 98 5 9
# Warning: could not find ARG role  en-ud-dev.conllu 985 21 21
# Warning: could not find ARG role  en-ud-dev.conllu 985 21 21
# Warning: could not find ARG role  en-ud-dev.conllu 986 29 29
# Warning: could not find ARG role  en-ud-dev.conllu 986 29 29
# Warning: could not find ARG role  en-ud-test.conllu 1004 11 11
# Warning: could not find ARG role  en-ud-test.conllu 1004 11 11
# Warning: could not find ARG role  en-ud-test.conllu 1008 5 5
# Warning: could not find ARG role  en-ud-test.conllu 1008 5 5
# Warning: could not find ARG role  en-ud-test.conllu 1017 29 29
# Warning: could not find ARG role  en-ud-test.conllu 1017 29 29
# Warning: could not find ARG role  en-ud-test.conllu 1017 31 31
# Warning: could not find ARG role  en-ud-test.conllu 1017 31 31
# Warning: could not find ARG role  en-ud-test.conllu 1024 40 46
# Warning: could not find ARG role  en-ud-test.conllu 1024 40 46
# Warning: could not find ARG role  en-ud-test.conllu 1035 28 47
# Warning: could not find ARG role  en-ud-test.conllu 1035 28 47
# Warning: could not find ARG role  en-ud-test.conllu 1036 39 40
# Warning: could not find ARG role  en-ud-test.conllu 1036 39 40
# Warning: could not find ARG role  en-ud-test.conllu 1063 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1063 0 0
# Warning: could not find ARG role  en-ud-test.conllu 107 6 21
# Warning: could not find ARG role  en-ud-test.conllu 107 6 21
# Warning: could not find ARG role  en-ud-test.conllu 108 0 1
# Warning: could not find ARG role  en-ud-test.conllu 108 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1102 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1102 0 1
# Warning: could not find ARG role  en-ud-test.conllu 116 27 41
# Warning: could not find ARG role  en-ud-test.conllu 116 27 41
# Warning: could not find ARG role  en-ud-test.conllu 1216 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1216 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1315 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1315 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1321 4 4
# Warning: could not find ARG role  en-ud-test.conllu 1321 4 4
# Warning: could not find ARG role  en-ud-test.conllu 1339 0 5
# Warning: could not find ARG role  en-ud-test.conllu 1339 0 5
# Warning: could not find ARG role  en-ud-test.conllu 14 0 0
# Warning: could not find ARG role  en-ud-test.conllu 14 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1430 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1430 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1511 11 19
# Warning: could not find ARG role  en-ud-test.conllu 1511 11 19
# Warning: could not find ARG role  en-ud-test.conllu 1511 9 9
# Warning: could not find ARG role  en-ud-test.conllu 1511 9 9
# Warning: could not find ARG role  en-ud-test.conllu 1512 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1512 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1521 0 3
# Warning: could not find ARG role  en-ud-test.conllu 1521 0 3
# Warning: could not find ARG role  en-ud-test.conllu 156 0 7
# Warning: could not find ARG role  en-ud-test.conllu 156 0 7
# Warning: could not find ARG role  en-ud-test.conllu 16 5 5
# Warning: could not find ARG role  en-ud-test.conllu 16 5 5
# Warning: could not find ARG role  en-ud-test.conllu 164 2 2
# Warning: could not find ARG role  en-ud-test.conllu 164 2 2
# Warning: could not find ARG role  en-ud-test.conllu 1648 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1648 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1689 0 2
# Warning: could not find ARG role  en-ud-test.conllu 1689 0 2
# Warning: could not find ARG role  en-ud-test.conllu 1689 20 21
# Warning: could not find ARG role  en-ud-test.conllu 1689 20 21
# Warning: could not find ARG role  en-ud-test.conllu 1765 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1765 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1793 5 11
# Warning: could not find ARG role  en-ud-test.conllu 1793 5 11
# Warning: could not find ARG role  en-ud-test.conllu 18 0 0
# Warning: could not find ARG role  en-ud-test.conllu 18 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1845 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1845 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1877 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1877 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1888 7 8
# Warning: could not find ARG role  en-ud-test.conllu 1888 7 8
# Warning: could not find ARG role  en-ud-test.conllu 1889 0 1
# Warning: could not find ARG role  en-ud-test.conllu 1889 0 1
# Warning: could not find ARG role  en-ud-test.conllu 197 0 1
# Warning: could not find ARG role  en-ud-test.conllu 197 0 1
# Warning: could not find ARG role  en-ud-test.conllu 198 0 0
# Warning: could not find ARG role  en-ud-test.conllu 198 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1981 0 0
# Warning: could not find ARG role  en-ud-test.conllu 1981 0 0
# Warning: could not find ARG role  en-ud-test.conllu 206 6 8
# Warning: could not find ARG role  en-ud-test.conllu 206 6 8
# Warning: could not find ARG role  en-ud-test.conllu 228 0 0
# Warning: could not find ARG role  en-ud-test.conllu 228 0 0
# Warning: could not find ARG role  en-ud-test.conllu 256 0 0
# Warning: could not find ARG role  en-ud-test.conllu 256 0 0
# Warning: could not find ARG role  en-ud-test.conllu 355 5 20
# Warning: could not find ARG role  en-ud-test.conllu 355 5 20
# Warning: could not find ARG role  en-ud-test.conllu 417 3 6
# Warning: could not find ARG role  en-ud-test.conllu 417 3 6
# Warning: could not find ARG role  en-ud-test.conllu 417 0 1
# Warning: could not find ARG role  en-ud-test.conllu 417 0 1
# Warning: could not find ARG role  en-ud-test.conllu 558 7 8
# Warning: could not find ARG role  en-ud-test.conllu 558 7 8
# Warning: could not find ARG role  en-ud-test.conllu 559 8 10
# Warning: could not find ARG role  en-ud-test.conllu 559 8 10
# Warning: could not find ARG role  en-ud-test.conllu 560 5 44
# Warning: could not find ARG role  en-ud-test.conllu 560 5 44
# Warning: could not find ARG role  en-ud-test.conllu 570 13 13
# Warning: could not find ARG role  en-ud-test.conllu 570 13 13
# Warning: could not find ARG role  en-ud-test.conllu 61 0 0
# Warning: could not find ARG role  en-ud-test.conllu 61 0 0
# Warning: could not find ARG role  en-ud-test.conllu 631 0 4
# Warning: could not find ARG role  en-ud-test.conllu 631 0 4
# Warning: could not find ARG role  en-ud-test.conllu 891 0 1
# Warning: could not find ARG role  en-ud-test.conllu 891 0 1
# Warning: could not find ARG role  en-ud-test.conllu 962 0 0
# Warning: could not find ARG role  en-ud-test.conllu 963 0 1
# Warning: could not find ARG role  en-ud-test.conllu 964 24 31
# Warning: could not find ARG role  en-ud-test.conllu 964 24 31
# Warning: could not find ARG role  en-ud-train.conllu 10010 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10010 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10456 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10456 0 0
# Warning: could not find ARG role  en-ud-train.conllu 1048 0 0
# Warning: could not find ARG role  en-ud-train.conllu 1048 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10542 14 14
# Warning: could not find ARG role  en-ud-train.conllu 10542 14 14
# Warning: could not find ARG role  en-ud-train.conllu 10564 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10564 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10565 0 1
# Warning: could not find ARG role  en-ud-train.conllu 10565 0 1
# Warning: could not find ARG role  en-ud-train.conllu 10571 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10571 0 0
# Warning: could not find ARG role  en-ud-train.conllu 10607 13 13
# Warning: could not find ARG role  en-ud-train.conllu 10607 13 13
# Warning: could not find ARG role  en-ud-train.conllu 10607 0 11
# Warning: could not find ARG role  en-ud-train.conllu 10607 0 11
# Warning: could not find ARG role  en-ud-train.conllu 10610 0 0
# Warning: could not find ARG role  en-ud-train.conllu 
0 0
# Warning: could not find ARG role  en-ud-train.conllu 7879 0 0
# Warning: could not find ARG role  en-ud-train.conllu 7949 4 7
# Warning: could not find ARG role  en-ud-train.conllu 7949 4 7
# Warning: could not find ARG role  en-ud-train.conllu 7949 2 2
# Warning: could not find ARG role  en-ud-train.conllu 7949 2 2
# Warning: could not find ARG role  en-ud-train.conllu 7954 0 1
# Warning: could not find ARG role  en-ud-train.conllu 7954 0 1
# Warning: could not find ARG role  en-ud-train.conllu 7967 6 13
# Warning: could not find ARG role  en-ud-train.conllu 7967 6 13
# Warning: could not find ARG role  en-ud-train.conllu 7967 3 4
# Warning: could not find ARG role  en-ud-train.conllu 7967 3 4
# Warning: could not find ARG role  en-ud-train.conllu 811 1 2
# Warning: could not find ARG role  en-ud-train.conllu 811 1 2
# Warning: could not find ARG role  en-ud-train.conllu 8151 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8151 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8162 0 2
# Warning: could not find ARG role  en-ud-train.conllu 8162 0 2
# Warning: could not find ARG role  en-ud-train.conllu 8231 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8231 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8237 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8237 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8301 0 0
# Warning: could not find ARG role  en-ud-train.conllu 834 0 2
# Warning: could not find ARG role  en-ud-train.conllu 835 13 15
# Warning: could not find ARG role  en-ud-train.conllu 835 13 15
# Warning: could not find ARG role  en-ud-train.conllu 8350 15 15
# Warning: could not find ARG role  en-ud-train.conllu 8350 15 15
# Warning: could not find ARG role  en-ud-train.conllu 8352 12 12
# Warning: could not find ARG role  en-ud-train.conllu 8352 12 12
# Warning: could not find ARG role  en-ud-train.conllu 837 3 8
# Warning: could not find ARG role  en-ud-train.conllu 837 3 8
# Warning: could not find ARG role  en-ud-train.conllu 8381 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8381 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8416 2 6
# Warning: could not find ARG role  en-ud-train.conllu 8416 2 6
# Warning: could not find ARG role  en-ud-train.conllu 8416 8 10
# Warning: could not find ARG role  en-ud-train.conllu 8416 8 10
# Warning: could not find ARG role  en-ud-train.conllu 8430 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8430 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8432 3 3
# Warning: could not find ARG role  en-ud-train.conllu 8432 3 3
# Warning: could not find ARG role  en-ud-train.conllu 8442 7 12
# Warning: could not find ARG role  en-ud-train.conllu 8442 7 12
# Warning: could not find ARG role  en-ud-train.conllu 8444 11 34
# Warning: could not find ARG role  en-ud-train.conllu 8444 11 34
# Warning: could not find ARG role  en-ud-train.conllu 8462 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8462 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8481 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8481 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8547 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8547 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8619 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8619 0 0
# Warning: could not find ARG role  en-ud-train.conllu 862 11 14
# Warning: could not find ARG role  en-ud-train.conllu 862 11 14
# Warning: could not find ARG role  en-ud-train.conllu 8783 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8783 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8831 0 3
# Warning: could not find ARG role  en-ud-train.conllu 8831 0 3
# Warning: could not find ARG role  en-ud-train.conllu 8833 0 2
# Warning: could not find ARG role  en-ud-train.conllu 8833 0 2
# Warning: could not find ARG role  en-ud-train.conllu 8836 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8836 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8868 3 3
# Warning: could not find ARG role  en-ud-train.conllu 8868 3 3
# Warning: could not find ARG role  en-ud-train.conllu 8873 5 8
# Warning: could not find ARG role  en-ud-train.conllu 8873 5 8
# Warning: could not find ARG role  en-ud-train.conllu 8882 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8882 0 0
# Warning: could not find ARG role  en-ud-train.conllu 894 0 1
# Warning: could not find ARG role  en-ud-train.conllu 894 0 1
# Warning: could not find ARG role  en-ud-train.conllu 8988 0 0
# Warning: could not find ARG role  en-ud-train.conllu 8988 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9016 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9016 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9034 0 8
# Warning: could not find ARG role  en-ud-train.conllu 9034 0 8
# Warning: could not find ARG role  en-ud-train.conllu 9034 10 15
# Warning: could not find ARG role  en-ud-train.conllu 9034 10 15
# Warning: could not find ARG role  en-ud-train.conllu 9038 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9038 0 0
# Warning: could not find ARG role  en-ud-train.conllu 905 32 36
# Warning: could not find ARG role  en-ud-train.conllu 905 32 36
# Warning: could not find ARG role  en-ud-train.conllu 9149 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9149 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9149 2 2
# Warning: could not find ARG role  en-ud-train.conllu 9149 2 2
# Warning: could not find ARG role  en-ud-train.conllu 916 48 48
# Warning: could not find ARG role  en-ud-train.conllu 916 48 48
# Warning: could not find ARG role  en-ud-train.conllu 916 37 45
# Warning: could not find ARG role  en-ud-train.conllu 916 37 45
# Warning: could not find ARG role  en-ud-train.conllu 917 0 17
# Warning: could not find ARG role  en-ud-train.conllu 917 0 17
# Warning: could not find ARG role  en-ud-train.conllu 918 0 3
# Warning: could not find ARG role  en-ud-train.conllu 918 0 3
# Warning: could not find ARG role  en-ud-train.conllu 919 0 1
# Warning: could not find ARG role  en-ud-train.conllu 919 0 1
# Warning: could not find ARG role  en-ud-train.conllu 919 11 12
# Warning: could not find ARG role  en-ud-train.conllu 919 11 12
# Warning: could not find ARG role  en-ud-train.conllu 923 0 0
# Warning: could not find ARG role  en-ud-train.conllu 923 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9266 7 7
# Warning: could not find ARG role  en-ud-train.conllu 9266 7 7
# Warning: could not find ARG role  en-ud-train.conllu 9266 9 14
# Warning: could not find ARG role  en-ud-train.conllu 9266 9 14
# Warning: could not find ARG role  en-ud-train.conllu 9272 0 1
# Warning: could not find ARG role  en-ud-train.conllu 9272 0 1
# Warning: could not find ARG role  en-ud-train.conllu 9304 0 1
# Warning: could not find ARG role  en-ud-train.conllu 9304 0 1
# Warning: could not find ARG role  en-ud-train.conllu 9318 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9318 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9335 0 8
# Warning: could not find ARG role  en-ud-train.conllu 9335 0 8
# Warning: could not find ARG role  en-ud-train.conllu 9340 5 12
# Warning: could not find ARG role  en-ud-train.conllu 9340 5 12
# Warning: could not find ARG role  en-ud-train.conllu 9340 3 3
# Warning: could not find ARG role  en-ud-train.conllu 9340 3 3
# Warning: could not find ARG role  en-ud-train.conllu 937 0 0
# Warning: could not find ARG role  en-ud-train.conllu 937 0 0
# Warning: could not find ARG role  en-ud-train.conllu 938 0 0
# Warning: could not find ARG role  en-ud-train.conllu 938 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9380 8 22
# Warning: could not find ARG role  en-ud-train.conllu 9380 8 22
# Warning: could not find ARG role  en-ud-train.conllu 945 5 6
# Warning: could not find ARG role  en-ud-train.conllu 945 5 6
# Warning: could not find ARG role  en-ud-train.conllu 945 3 3
# Warning: could not find ARG role  en-ud-train.conllu 945 3 3
# Warning: could not find ARG role  en-ud-train.conllu 9481 0 2
# Warning: could not find ARG role  en-ud-train.conllu 9481 0 2
# Warning: could not find ARG role  en-ud-train.conllu 9509 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9509 0 0
# Warning: could not find ARG role  en-ud-train.conllu 958 8 12
# Warning: could not find ARG role  en-ud-train.conllu 958 8 12
# Warning: could not find ARG role  en-ud-train.conllu 958 5 6
# Warning: could not find ARG role  en-ud-train.conllu 958 5 6
# Warning: could not find ARG role  en-ud-train.conllu 9594 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9594 0 0
# Warning: could not find ARG role  en-ud-train.conllu 980 10 10
# Warning: could not find ARG role  en-ud-train.conllu 980 10 10
# Warning: could not find ARG role  en-ud-train.conllu 9842 0 0
# Warning: could not find ARG role  en-ud-train.conllu 9842 0 0
# Warning: could not find ARG role  en-ud-train.conllu 990 4 5
# Warning: could not find ARG role  en-ud-train.conllu 990 4 5
# Warning: could not find ARG role  en-ud-train.conllu 992 5 5
# Warning: could not find ARG role  en-ud-train.conllu 992 5 5
# (7499, 48)
#                    Sentence.ID Pred.Lemma  Arg.Phrase Pred.Token  \
# Property
# 0           en-ud-dev.conllu 1       come  this story          3
# 1           en-ud-dev.conllu 1       come  this story          3
# 2         en-ud-dev.conllu 100        cry     America          1
# 3         en-ud-dev.conllu 100        cry     America          1
# 4         en-ud-dev.conllu 100        cry        wolf          1
#
#          Arg.Tokens.Begin Arg.Tokens.End Gram.Func Split Sent.Grammatical  \
# Property
# 0                       4              5     nsubj   dev              5.0
# 1                       4              5     nsubj   dev              5.0
# 2                       0              0     nsubj   dev              2.0
# 3                       0              0     nsubj   dev              5.0
# 4                       2              2      dobj   dev              5.0
#
#          Annotator.ID  ...                                               tree  \
# Property               ...
# 0                   7  ...  [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 1                  20  ...  [[[From], [(DT the), (NNP AP)]], [[comes]], [[...
# 2                  46  ...  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 3                  15  ...  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
# 4                  26  ...  [[[America], [(VBD cried), (NP+NN wolf), (PP-L...
#
#                                                    sentence  \
# Property
# 0                            From the AP comes this story :
# 1                            From the AP comes this story :
# 2         America cried wolf in Iraq , and what 's scary...
# 3         America cried wolf in Iraq , and what 's scary...
# 4         America cried wolf in Iraq , and what 's scary...
#
#                                                 spacy_parse  \
# Property
# 0         {'text': 'From the AP comes this story : ', 's...
# 1         {'text': 'From the AP comes this story : ', 's...
# 2         {'text': 'America cried wolf in Iraq, and what...
# 3         {'text': 'America cried wolf in Iraq, and what...
# 4         {'text': 'America cried wolf in Iraq, and what...
#
#                    Arg.Tree Arg.treepos Predicate Arg.Stripped  \
# Property
# 0         [[this], [story]]        (2,)     comes   this story
# 1         [[this], [story]]        (2,)     comes   this story
# 2                 [America]      (0, 0)     cried      America
# 3                 [America]      (0, 0)     cried      America
# 4                    [wolf]   (0, 1, 1)     cried         wolf
#
#                                                   Arg.Parse  Roleset Arg
# Property
# 0         {'text': 'this story ', 'sents': [{'start': 0,...  come.03   1
# 1         {'text': 'this story ', 'sents': [{'start': 0,...  come.03   1
# 2         {'text': 'America ', 'sents': [{'start': 0, 'e...   cry.01   0
# 3         {'text': 'America ', 'sents': [{'start': 0, 'e...   cry.01   0
# 4         {'text': 'wolf ', 'sents': [{'start': 0, 'end'...   cry.01   1
#
# [5 rows x 48 columns]

# %%
# roles_wide = roles_wide.drop(columns=["tree", "spacy_parse", "Arg.Tree", "Arg.treepos"])
roles_wide.to_csv("decomp_ud_modified_sentences.csv")
